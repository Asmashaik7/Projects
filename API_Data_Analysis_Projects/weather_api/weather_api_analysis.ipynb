# %% [markdown]
# # Weather API Data Analysis – 10 Day Forecast

# %% [markdown]
# ## Objective
# To analyze 10-day weather forecast data for a selected city using a public Weather API, extract daily minimum and maximum temperatures, and identify the highest and lowest temperatures across the forecast period to understand short-term temperature patterns.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import requests
import json
from datetime import datetime

import os

from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("OPENWEATHER_API_KEY")

# %% [markdown]
# ## Data Source
# Weather data of Hyderabad city, India is fetched using the OpenWeather API, which returns forecast data in JSON format.

# %% [markdown]
# ## 2. API URL & Request

# %%
url=f'https://api.openweathermap.org/data/2.5/forecast?q=Hyderabad,IN&units=metric&appid={API_KEY}'
resp=requests.get(url)

# %% [markdown]
# ## 3. Response Validation

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/forecast?q=Hyderabad,IN&units=metric&appid=54135abe53160ca54ae7094dedd58391

# %%
print(API_KEY)
# Out:
# 54135abe53160ca54ae7094dedd58391

# %%
print(resp.status_code)
# Out:
# 200

# %%
if resp.status_code==200:
    print("Response object loaded successfully")
    data=resp.content
else:
    print("Response object failed to load")
# Out:
# Response object loaded successfully

# %%
type(data)
# Out:
# bytes

# %% [markdown]
# ---
# ## 4. JSON Parsing (Bytes → Python Dictionary)

# %%
data=json.loads(data)

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1767808800,
#    'main': {'temp': 18.01,
#     'feels_like': 16.83,
#     'temp_min': 18.01,
#     'temp_max': 18.01,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 954,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 1.91, 'deg': 80, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 18:00:00'},
#   {'dt': 1767819600,
#    'main': {'temp': 17.43,
#     'feels_like': 16.22,
#     'temp_min': 16.28,
#     'temp_max': 17.43,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 953,
#     'humidity': 38,
#     'temp_kf': 1.15},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 2.73, 'deg': 84, 'gust': 3.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 21:00:00'},
#   {'dt': 1767830400,
#    'main': {'temp': 15.88,
#     'feels_like': 15.04,
#     'temp_min': 14.81,
#     'temp_max': 15.88,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 953,
#     'humidity': 58,
#     'temp_kf': 1.07},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.15, 'deg': 99, 'gust': 2.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-08 00:00:00'},
#   {'dt': 1767841200,
#    'main': {'temp': 18.07,
#     'feels_like': 17.81,
#     'temp_min': 18.07,
#     'temp_max': 18.07,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 955,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.91, 'deg': 128, 'gust': 4.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-08 03:00:00'},
#   {'dt': 1767852000,
#    'main': {'temp': 24.17,
#     'feels_like': 23.56,
#     'temp_min': 24.17,
#     'temp_max': 24.17,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.79, 'deg': 100, 'gust': 4.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-08 06:00:00'},
#   {'dt': 1767862800,
#    'main': {'temp': 26.12,
#     'feels_like': 26.12,
#     'temp_min': 26.12,
#     'temp_max': 26.12,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 3.8, 'deg': 93, 'gust': 3.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-08 09:00:00'},
#   {'dt': 1767873600,
#    'main': {'temp': 23.7,
#     'feels_like': 22.96,
#     'temp_min': 23.7,
#     'temp_max': 23.7,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 3.29, 'deg': 101, 'gust': 3.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-08 12:00:00'},
#   {'dt': 1767884400,
#    'main': {'temp': 20.23,
#     'feels_like': 19.3,
#     'temp_min': 20.23,
#     'temp_max': 20.23,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 38},
#    'wind': {'speed': 3.34, 'deg': 123, 'gust': 4.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-08 15:00:00'},
#   {'dt': 1767895200,
#    'main': {'temp': 18.93,
#     'feels_like': 17.98,
#     'temp_min': 18.93,
#     'temp_max': 18.93,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 1.94, 'deg': 97, 'gust': 2.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-08 18:00:00'},
#   {'dt': 1767906000,
#    'main': {'temp': 17.32,
#     'feels_like': 16.33,
#     'temp_min': 17.32,
#     'temp_max': 17.32,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 2.54, 'deg': 96, 'gust': 3.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-08 21:00:00'},
#   {'dt': 1767916800,
#    'main': {'temp': 15.78,
#     'feels_like': 14.8,
#     'temp_min': 15.78,
#     'temp_max': 15.78,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.77, 'deg': 84, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-09 00:00:00'},
#   {'dt': 1767927600,
#    'main': {'temp': 17.83,
#     'feels_like': 17.29,
#     'temp_min': 17.83,
#     'temp_max': 17.83,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.9, 'deg': 107, 'gust': 4.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-09 03:00:00'},
#   {'dt': 1767938400,
#    'main': {'temp': 24.34,
#     'feels_like': 23.61,
#     'temp_min': 24.34,
#     'temp_max': 24.34,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.87, 'deg': 75, 'gust': 4.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-09 06:00:00'},
#   {'dt': 1767949200,
#    'main': {'temp': 26.61,
#     'feels_like': 26.61,
#     'temp_min': 26.61,
#     'temp_max': 26.61,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 4.08, 'deg': 75, 'gust': 3.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-09 09:00:00'},
#   {'dt': 1767960000,
#    'main': {'temp': 24.03,
#     'feels_like': 23.19,
#     'temp_min': 24.03,
#     'temp_max': 24.03,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.59, 'deg': 79, 'gust': 4.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-09 12:00:00'},
#   {'dt': 1767970800,
#    'main': {'temp': 19.84,
#     'feels_like': 18.74,
#     'temp_min': 19.84,
#     'temp_max': 19.84,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.17, 'deg': 73, 'gust': 4.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-09 15:00:00'},
#   {'dt': 1767981600,
#    'main': {'temp': 18.24,
#     'feels_like': 17.06,
#     'temp_min': 18.24,
#     'temp_max': 18.24,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 953,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 1.73, 'deg': 88, 'gust': 2.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-09 18:00:00'},
#   {'dt': 1767992400,
#    'main': {'temp': 17.33,
#     'feels_like': 16.08,
#     'temp_min': 17.33,
#     'temp_max': 17.33,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 1.91, 'deg': 70, 'gust': 2.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-09 21:00:00'},
#   {'dt': 1768003200,
#    'main': {'temp': 15.63,
#     'feels_like': 14.29,
#     'temp_min': 15.63,
#     'temp_max': 15.63,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 2.16, 'deg': 61, 'gust': 2.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-10 00:00:00'},
#   {'dt': 1768014000,
#    'main': {'temp': 18.99,
#     'feels_like': 17.83,
#     'temp_min': 18.99,
#     'temp_max': 18.99,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 32},
#    'wind': {'speed': 2.3, 'deg': 74, 'gust': 3.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-10 03:00:00'},
#   {'dt': 1768024800,
#    'main': {'temp': 24.66,
#     'feels_like': 23.81,
#     'temp_min': 24.66,
#     'temp_max': 24.66,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 2.8, 'deg': 72, 'gust': 2.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-10 06:00:00'},
#   {'dt': 1768035600,
#    'main': {'temp': 26.91,
#     'feels_like': 26.03,
#     'temp_min': 26.91,
#     'temp_max': 26.91,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 20,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.87, 'deg': 79, 'gust': 2.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-10 09:00:00'},
#   {'dt': 1768046400,
#    'main': {'temp': 24.17,
#     'feels_like': 23.35,
#     'temp_min': 24.17,
#     'temp_max': 24.17,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 78},
#    'wind': {'speed': 3.35, 'deg': 88, 'gust': 4.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-10 12:00:00'},
#   {'dt': 1768057200,
#    'main': {'temp': 20.23,
#     'feels_like': 19.22,
#     'temp_min': 20.23,
#     'temp_max': 20.23,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 953,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.7, 'deg': 87, 'gust': 3.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-10 15:00:00'},
#   {'dt': 1768068000,
#    'main': {'temp': 18.36,
#     'feels_like': 17.24,
#     'temp_min': 18.36,
#     'temp_max': 18.36,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 953,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 2.09, 'deg': 62, 'gust': 2.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-10 18:00:00'},
#   {'dt': 1768078800,
#    'main': {'temp': 17.54,
#     'feels_like': 16.34,
#     'temp_min': 17.54,
#     'temp_max': 17.54,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 1.35, 'deg': 78, 'gust': 1.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-10 21:00:00'},
#   {'dt': 1768089600,
#    'main': {'temp': 16.27,
#     'feels_like': 15.02,
#     'temp_min': 16.27,
#     'temp_max': 16.27,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 2.24, 'deg': 92, 'gust': 2.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-11 00:00:00'},
#   {'dt': 1768100400,
#    'main': {'temp': 18.98,
#     'feels_like': 17.87,
#     'temp_min': 18.98,
#     'temp_max': 18.98,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 955,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.13, 'deg': 71, 'gust': 3.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-11 03:00:00'},
#   {'dt': 1768111200,
#    'main': {'temp': 25.58,
#     'feels_like': 24.74,
#     'temp_min': 25.58,
#     'temp_max': 25.58,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 21,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.38, 'deg': 67, 'gust': 3.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-11 06:00:00'},
#   {'dt': 1768122000,
#    'main': {'temp': 27.71,
#     'feels_like': 26.5,
#     'temp_min': 27.71,
#     'temp_max': 27.71,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 18,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 3.5, 'deg': 67, 'gust': 3.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-11 09:00:00'},
#   {'dt': 1768132800,
#    'main': {'temp': 24.91,
#     'feels_like': 24.06,
#     'temp_min': 24.91,
#     'temp_max': 24.91,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 3.61, 'deg': 74, 'gust': 5.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-11 12:00:00'},
#   {'dt': 1768143600,
#    'main': {'temp': 20.26,
#     'feels_like': 19.18,
#     'temp_min': 20.26,
#     'temp_max': 20.26,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 3.48, 'deg': 54, 'gust': 5.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-11 15:00:00'},
#   {'dt': 1768154400,
#    'main': {'temp': 18.81,
#     'feels_like': 17.66,
#     'temp_min': 18.81,
#     'temp_max': 18.81,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 2.05, 'deg': 65, 'gust': 2.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-11 18:00:00'},
#   {'dt': 1768165200,
#    'main': {'temp': 17.76,
#     'feels_like': 16.56,
#     'temp_min': 17.76,
#     'temp_max': 17.76,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 2.03, 'deg': 99, 'gust': 2.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-11 21:00:00'},
#   {'dt': 1768176000,
#    'main': {'temp': 16.33,
#     'feels_like': 15.12,
#     'temp_min': 16.33,
#     'temp_max': 16.33,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 2.19, 'deg': 84, 'gust': 2.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-12 00:00:00'},
#   {'dt': 1768186800,
#    'main': {'temp': 19.09,
#     'feels_like': 18.49,
#     'temp_min': 19.09,
#     'temp_max': 19.09,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.34, 'deg': 101, 'gust': 3.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-12 03:00:00'},
#   {'dt': 1768197600,
#    'main': {'temp': 25.73,
#     'feels_like': 25.14,
#     'temp_min': 25.73,
#     'temp_max': 25.73,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.46, 'deg': 90, 'gust': 3.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-12 06:00:00'},
#   {'dt': 1768208400,
#    'main': {'temp': 27.81,
#     'feels_like': 26.76,
#     'temp_min': 27.81,
#     'temp_max': 27.81,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 25,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 3.13, 'deg': 98, 'gust': 2.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-12 09:00:00'},
#   {'dt': 1768219200,
#    'main': {'temp': 25.83,
#     'feels_like': 25.25,
#     'temp_min': 25.83,
#     'temp_max': 25.83,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 3.14, 'deg': 104, 'gust': 3.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-12 12:00:00'},
#   {'dt': 1768230000,
#    'main': {'temp': 21.83,
#     'feels_like': 21.09,
#     'temp_min': 21.83,
#     'temp_max': 21.83,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.6, 'deg': 111, 'gust': 3.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-12 15:00:00'}],
#  'city': {'id': 1269843,
#   'name': 'Hyderabad',
#   'coord': {'lat': 17.3753, 'lon': 78.4744},
#   'country': 'IN',
#   'population': 3597816,
#   'timezone': 19800,
#   'sunrise': 1767748672,
#   'sunset': 1767788768}}

# %% [markdown]
# ## 5. Data Structure Exploration

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
print(type(data['list']))
# Out:
# <class 'list'>

# %%
data['list']
# Out:
# [{'dt': 1767808800,
#   'main': {'temp': 18.01,
#    'feels_like': 16.83,
#    'temp_min': 18.01,
#    'temp_max': 18.01,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 954,
#    'humidity': 37,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 1.91, 'deg': 80, 'gust': 2.45},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 18:00:00'},
#  {'dt': 1767819600,
#   'main': {'temp': 17.43,
#    'feels_like': 16.22,
#    'temp_min': 16.28,
#    'temp_max': 17.43,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 953,
#    'humidity': 38,
#    'temp_kf': 1.15},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 2.73, 'deg': 84, 'gust': 3.58},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 21:00:00'},
#  {'dt': 1767830400,
#   'main': {'temp': 15.88,
#    'feels_like': 15.04,
#    'temp_min': 14.81,
#    'temp_max': 15.88,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 953,
#    'humidity': 58,
#    'temp_kf': 1.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 5},
#   'wind': {'speed': 2.15, 'deg': 99, 'gust': 2.69},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-08 00:00:00'},
#  {'dt': 1767841200,
#   'main': {'temp': 18.07,
#    'feels_like': 17.81,
#    'temp_min': 18.07,
#    'temp_max': 18.07,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 955,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 2.91, 'deg': 128, 'gust': 4.01},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-08 03:00:00'},
#  {'dt': 1767852000,
#   'main': {'temp': 24.17,
#    'feels_like': 23.56,
#    'temp_min': 24.17,
#    'temp_max': 24.17,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 35,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 3.79, 'deg': 100, 'gust': 4.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-08 06:00:00'},
#  {'dt': 1767862800,
#   'main': {'temp': 26.12,
#    'feels_like': 26.12,
#    'temp_min': 26.12,
#    'temp_max': 26.12,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 952,
#    'humidity': 26,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 12},
#   'wind': {'speed': 3.8, 'deg': 93, 'gust': 3.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-08 09:00:00'},
#  {'dt': 1767873600,
#   'main': {'temp': 23.7,
#    'feels_like': 22.96,
#    'temp_min': 23.7,
#    'temp_max': 23.7,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 32,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 3.29, 'deg': 101, 'gust': 3.96},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-08 12:00:00'},
#  {'dt': 1767884400,
#   'main': {'temp': 20.23,
#    'feels_like': 19.3,
#    'temp_min': 20.23,
#    'temp_max': 20.23,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 38,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 38},
#   'wind': {'speed': 3.34, 'deg': 123, 'gust': 4.84},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-08 15:00:00'},
#  {'dt': 1767895200,
#   'main': {'temp': 18.93,
#    'feels_like': 17.98,
#    'temp_min': 18.93,
#    'temp_max': 18.93,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 1.94, 'deg': 97, 'gust': 2.28},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-08 18:00:00'},
#  {'dt': 1767906000,
#   'main': {'temp': 17.32,
#    'feels_like': 16.33,
#    'temp_min': 17.32,
#    'temp_max': 17.32,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 47,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 2.54, 'deg': 96, 'gust': 3.09},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-08 21:00:00'},
#  {'dt': 1767916800,
#   'main': {'temp': 15.78,
#    'feels_like': 14.8,
#    'temp_min': 15.78,
#    'temp_max': 15.78,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 53,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 2.77, 'deg': 84, 'gust': 3.5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-09 00:00:00'},
#  {'dt': 1767927600,
#   'main': {'temp': 17.83,
#    'feels_like': 17.29,
#    'temp_min': 17.83,
#    'temp_max': 17.83,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 62,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 2.9, 'deg': 107, 'gust': 4.57},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-09 03:00:00'},
#  {'dt': 1767938400,
#   'main': {'temp': 24.34,
#    'feels_like': 23.61,
#    'temp_min': 24.34,
#    'temp_max': 24.34,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 30,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 3.87, 'deg': 75, 'gust': 4.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-09 06:00:00'},
#  {'dt': 1767949200,
#   'main': {'temp': 26.61,
#    'feels_like': 26.61,
#    'temp_min': 26.61,
#    'temp_max': 26.61,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 22,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 34},
#   'wind': {'speed': 4.08, 'deg': 75, 'gust': 3.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-09 09:00:00'},
#  {'dt': 1767960000,
#   'main': {'temp': 24.03,
#    'feels_like': 23.19,
#    'temp_min': 24.03,
#    'temp_max': 24.03,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 27,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 3.59, 'deg': 79, 'gust': 4.76},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-09 12:00:00'},
#  {'dt': 1767970800,
#   'main': {'temp': 19.84,
#    'feels_like': 18.74,
#    'temp_min': 19.84,
#    'temp_max': 19.84,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 33,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 3.17, 'deg': 73, 'gust': 4.5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-09 15:00:00'},
#  {'dt': 1767981600,
#   'main': {'temp': 18.24,
#    'feels_like': 17.06,
#    'temp_min': 18.24,
#    'temp_max': 18.24,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 953,
#    'humidity': 36,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 1.73, 'deg': 88, 'gust': 2.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-09 18:00:00'},
#  {'dt': 1767992400,
#   'main': {'temp': 17.33,
#    'feels_like': 16.08,
#    'temp_min': 17.33,
#    'temp_max': 17.33,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 37,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 86},
#   'wind': {'speed': 1.91, 'deg': 70, 'gust': 2.13},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-09 21:00:00'},
#  {'dt': 1768003200,
#   'main': {'temp': 15.63,
#    'feels_like': 14.29,
#    'temp_min': 15.63,
#    'temp_max': 15.63,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 40,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 44},
#   'wind': {'speed': 2.16, 'deg': 61, 'gust': 2.57},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-10 00:00:00'},
#  {'dt': 1768014000,
#   'main': {'temp': 18.99,
#    'feels_like': 17.83,
#    'temp_min': 18.99,
#    'temp_max': 18.99,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 34,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 32},
#   'wind': {'speed': 2.3, 'deg': 74, 'gust': 3.37},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-10 03:00:00'},
#  {'dt': 1768024800,
#   'main': {'temp': 24.66,
#    'feels_like': 23.81,
#    'temp_min': 24.66,
#    'temp_max': 24.66,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 24,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 2.8, 'deg': 72, 'gust': 2.79},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-10 06:00:00'},
#  {'dt': 1768035600,
#   'main': {'temp': 26.91,
#    'feels_like': 26.03,
#    'temp_min': 26.91,
#    'temp_max': 26.91,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 20,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 2.87, 'deg': 79, 'gust': 2.26},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-10 09:00:00'},
#  {'dt': 1768046400,
#   'main': {'temp': 24.17,
#    'feels_like': 23.35,
#    'temp_min': 24.17,
#    'temp_max': 24.17,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 27,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 78},
#   'wind': {'speed': 3.35, 'deg': 88, 'gust': 4.49},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-10 12:00:00'},
#  {'dt': 1768057200,
#   'main': {'temp': 20.23,
#    'feels_like': 19.22,
#    'temp_min': 20.23,
#    'temp_max': 20.23,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 953,
#    'humidity': 35,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 2.7, 'deg': 87, 'gust': 3.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-10 15:00:00'},
#  {'dt': 1768068000,
#   'main': {'temp': 18.36,
#    'feels_like': 17.24,
#    'temp_min': 18.36,
#    'temp_max': 18.36,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 953,
#    'humidity': 38,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 17},
#   'wind': {'speed': 2.09, 'deg': 62, 'gust': 2.5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-10 18:00:00'},
#  {'dt': 1768078800,
#   'main': {'temp': 17.54,
#    'feels_like': 16.34,
#    'temp_min': 17.54,
#    'temp_max': 17.54,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 38,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 1.35, 'deg': 78, 'gust': 1.45},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-10 21:00:00'},
#  {'dt': 1768089600,
#   'main': {'temp': 16.27,
#    'feels_like': 15.02,
#    'temp_min': 16.27,
#    'temp_max': 16.27,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 41,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 2.24, 'deg': 92, 'gust': 2.88},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-11 00:00:00'},
#  {'dt': 1768100400,
#   'main': {'temp': 18.98,
#    'feels_like': 17.87,
#    'temp_min': 18.98,
#    'temp_max': 18.98,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 955,
#    'humidity': 36,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.13, 'deg': 71, 'gust': 3.43},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-11 03:00:00'},
#  {'dt': 1768111200,
#   'main': {'temp': 25.58,
#    'feels_like': 24.74,
#    'temp_min': 25.58,
#    'temp_max': 25.58,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 21,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 90},
#   'wind': {'speed': 3.38, 'deg': 67, 'gust': 3.98},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-11 06:00:00'},
#  {'dt': 1768122000,
#   'main': {'temp': 27.71,
#    'feels_like': 26.5,
#    'temp_min': 27.71,
#    'temp_max': 27.71,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 952,
#    'humidity': 18,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 73},
#   'wind': {'speed': 3.5, 'deg': 67, 'gust': 3.21},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-11 09:00:00'},
#  {'dt': 1768132800,
#   'main': {'temp': 24.91,
#    'feels_like': 24.06,
#    'temp_min': 24.91,
#    'temp_max': 24.91,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 23,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 61},
#   'wind': {'speed': 3.61, 'deg': 74, 'gust': 5.01},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-11 12:00:00'},
#  {'dt': 1768143600,
#   'main': {'temp': 20.26,
#    'feels_like': 19.18,
#    'temp_min': 20.26,
#    'temp_max': 20.26,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 32,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 56},
#   'wind': {'speed': 3.48, 'deg': 54, 'gust': 5.58},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-11 15:00:00'},
#  {'dt': 1768154400,
#   'main': {'temp': 18.81,
#    'feels_like': 17.66,
#    'temp_min': 18.81,
#    'temp_max': 18.81,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 35,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 40},
#   'wind': {'speed': 2.05, 'deg': 65, 'gust': 2.57},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-11 18:00:00'},
#  {'dt': 1768165200,
#   'main': {'temp': 17.76,
#    'feels_like': 16.56,
#    'temp_min': 17.76,
#    'temp_max': 17.76,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 37,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 2.03, 'deg': 99, 'gust': 2.29},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-11 21:00:00'},
#  {'dt': 1768176000,
#   'main': {'temp': 16.33,
#    'feels_like': 15.12,
#    'temp_min': 16.33,
#    'temp_max': 16.33,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 75},
#   'wind': {'speed': 2.19, 'deg': 84, 'gust': 2.82},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-12 00:00:00'},
#  {'dt': 1768186800,
#   'main': {'temp': 19.09,
#    'feels_like': 18.49,
#    'temp_min': 19.09,
#    'temp_max': 19.09,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 55,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 2.34, 'deg': 101, 'gust': 3.41},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-12 03:00:00'},
#  {'dt': 1768197600,
#   'main': {'temp': 25.73,
#    'feels_like': 25.14,
#    'temp_min': 25.73,
#    'temp_max': 25.73,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 30,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 3.46, 'deg': 90, 'gust': 3.56},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-12 06:00:00'},
#  {'dt': 1768208400,
#   'main': {'temp': 27.81,
#    'feels_like': 26.76,
#    'temp_min': 27.81,
#    'temp_max': 27.81,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 25,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 15},
#   'wind': {'speed': 3.13, 'deg': 98, 'gust': 2.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-12 09:00:00'},
#  {'dt': 1768219200,
#   'main': {'temp': 25.83,
#    'feels_like': 25.25,
#    'temp_min': 25.83,
#    'temp_max': 25.83,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 30,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 10},
#   'wind': {'speed': 3.14, 'deg': 104, 'gust': 3.69},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-12 12:00:00'},
#  {'dt': 1768230000,
#   'main': {'temp': 21.83,
#    'feels_like': 21.09,
#    'temp_min': 21.83,
#    'temp_max': 21.83,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 2.6, 'deg': 111, 'gust': 3.54},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-12 15:00:00'}]

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
data['list'][0] # we have our analysis required 'dt' in list, and min and max temperatures in temp list.
# Out:
# {'dt': 1767808800,
#  'main': {'temp': 18.01,
#   'feels_like': 16.83,
#   'temp_min': 18.01,
#   'temp_max': 18.01,
#   'pressure': 1019,
#   'sea_level': 1019,
#   'grnd_level': 954,
#   'humidity': 37,
#   'temp_kf': 0},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'clouds': {'all': 4},
#  'wind': {'speed': 1.91, 'deg': 80, 'gust': 2.45},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'n'},
#  'dt_txt': '2026-01-07 18:00:00'}

# %%
data['list'][0].keys()
# Out:
# dict_keys(['dt', 'main', 'weather', 'clouds', 'wind', 'visibility', 'pop', 'sys', 'dt_txt'])

# %%
print(type(data['list'][0]['main']))
# Out:
# <class 'dict'>

# %%
print(data['list'][0]['main'].keys())
# Out:
# dict_keys(['temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'sea_level', 'grnd_level', 'humidity', 'temp_kf'])

# %%
weather_list=data['list']
weather_list[0]['main']
# Out:
# {'temp': 18.01,
#  'feels_like': 16.83,
#  'temp_min': 18.01,
#  'temp_max': 18.01,
#  'pressure': 1019,
#  'sea_level': 1019,
#  'grnd_level': 954,
#  'humidity': 37,
#  'temp_kf': 0}

# %%
weather_list[0]['dt'] # use datetime
# Out:
# 1767808800

# %% [markdown]
# ## 6. Daily Temperature Extraction

# %%
from datetime import datetime, UTC
maxtemp=[]
mintemp=[] # to collect max and min temperatures from temp.

for each in weather_list:
    date_ts=each['dt'] #this gives unix timestamp
    date=datetime.fromtimestamp(date_ts, UTC).strftime('%d-%m-%y') #correct date conversion
    maxtemp=each['main']['temp_max']
    mintemp=each['main']['temp_min']

    print(f'Date:{date} | Min Temp: {mintemp} | Max Temp: {maxtemp}')
# Out:
# Date:07-01-26 | Min Temp: 18.01 | Max Temp: 18.01
# Date:07-01-26 | Min Temp: 16.28 | Max Temp: 17.43
# Date:08-01-26 | Min Temp: 14.81 | Max Temp: 15.88
# Date:08-01-26 | Min Temp: 18.07 | Max Temp: 18.07
# Date:08-01-26 | Min Temp: 24.17 | Max Temp: 24.17
# Date:08-01-26 | Min Temp: 26.12 | Max Temp: 26.12
# Date:08-01-26 | Min Temp: 23.7 | Max Temp: 23.7
# Date:08-01-26 | Min Temp: 20.23 | Max Temp: 20.23
# Date:08-01-26 | Min Temp: 18.93 | Max Temp: 18.93
# Date:08-01-26 | Min Temp: 17.32 | Max Temp: 17.32
# Date:09-01-26 | Min Temp: 15.78 | Max Temp: 15.78
# Date:09-01-26 | Min Temp: 17.83 | Max Temp: 17.83
# Date:09-01-26 | Min Temp: 24.34 | Max Temp: 24.34
# Date:09-01-26 | Min Temp: 26.61 | Max Temp: 26.61
# Date:09-01-26 | Min Temp: 24.03 | Max Temp: 24.03
# Date:09-01-26 | Min Temp: 19.84 | Max Temp: 19.84
# Date:09-01-26 | Min Temp: 18.24 | Max Temp: 18.24
# Date:09-01-26 | Min Temp: 17.33 | Max Temp: 17.33
# Date:10-01-26 | Min Temp: 15.63 | Max Temp: 15.63
# Date:10-01-26 | Min Temp: 18.99 | Max Temp: 18.99
# Date:10-01-26 | Min Temp: 24.66 | Max Temp: 24.66
# Date:10-01-26 | Min Temp: 26.91 | Max Temp: 26.91
# Date:10-01-26 | Min Temp: 24.17 | Max Temp: 24.17
# Date:10-01-26 | Min Temp: 20.23 | Max Temp: 20.23
# Date:10-01-26 | Min Temp: 18.36 | Max Temp: 18.36
# Date:10-01-26 | Min Temp: 17.54 | Max Temp: 17.54
# Date:11-01-26 | Min Temp: 16.27 | Max Temp: 16.27
# Date:11-01-26 | Min Temp: 18.98 | Max Temp: 18.98
# Date:11-01-26 | Min Temp: 25.58 | Max Temp: 25.58
# Date:11-01-26 | Min Temp: 27.71 | Max Temp: 27.71
# Date:11-01-26 | Min Temp: 24.91 | Max Temp: 24.91
# Date:11-01-26 | Min Temp: 20.26 | Max Temp: 20.26
# Date:11-01-26 | Min Temp: 18.81 | Max Temp: 18.81
# Date:11-01-26 | Min Temp: 17.76 | Max Temp: 17.76
# Date:12-01-26 | Min Temp: 16.33 | Max Temp: 16.33
# Date:12-01-26 | Min Temp: 19.09 | Max Temp: 19.09
# Date:12-01-26 | Min Temp: 25.73 | Max Temp: 25.73
# Date:12-01-26 | Min Temp: 27.81 | Max Temp: 27.81
# Date:12-01-26 | Min Temp: 25.83 | Max Temp: 25.83
# Date:12-01-26 | Min Temp: 21.83 | Max Temp: 21.83

# %% [markdown]
# ---
# ## 7: Daily Temperature Aggregation (CORE ANALYSIS)

# %% [markdown]
# ### 7.1 Create a structured list (row-wise data)

# %%
rows=[]
for each in weather_list:
    date=datetime.fromtimestamp(each['dt'],UTC).strftime('%d-%m-%y')
    min_temp=each['main']['temp_min']
    max_temp=each['main']['temp_max']

    rows.append([date,min_temp,max_temp])
rows #rows is a list, each item inside it is also a list. This structure is called List of lists
# Out:
# [['07-01-26', 18.01, 18.01],
#  ['07-01-26', 16.28, 17.43],
#  ['08-01-26', 14.81, 15.88],
#  ['08-01-26', 18.07, 18.07],
#  ['08-01-26', 24.17, 24.17],
#  ['08-01-26', 26.12, 26.12],
#  ['08-01-26', 23.7, 23.7],
#  ['08-01-26', 20.23, 20.23],
#  ['08-01-26', 18.93, 18.93],
#  ['08-01-26', 17.32, 17.32],
#  ['09-01-26', 15.78, 15.78],
#  ['09-01-26', 17.83, 17.83],
#  ['09-01-26', 24.34, 24.34],
#  ['09-01-26', 26.61, 26.61],
#  ['09-01-26', 24.03, 24.03],
#  ['09-01-26', 19.84, 19.84],
#  ['09-01-26', 18.24, 18.24],
#  ['09-01-26', 17.33, 17.33],
#  ['10-01-26', 15.63, 15.63],
#  ['10-01-26', 18.99, 18.99],
#  ['10-01-26', 24.66, 24.66],
#  ['10-01-26', 26.91, 26.91],
#  ['10-01-26', 24.17, 24.17],
#  ['10-01-26', 20.23, 20.23],
#  ['10-01-26', 18.36, 18.36],
#  ['10-01-26', 17.54, 17.54],
#  ['11-01-26', 16.27, 16.27],
#  ['11-01-26', 18.98, 18.98],
#  ['11-01-26', 25.58, 25.58],
#  ['11-01-26', 27.71, 27.71],
#  ['11-01-26', 24.91, 24.91],
#  ['11-01-26', 20.26, 20.26],
#  ['11-01-26', 18.81, 18.81],
#  ['11-01-26', 17.76, 17.76],
#  ['12-01-26', 16.33, 16.33],
#  ['12-01-26', 19.09, 19.09],
#  ['12-01-26', 25.73, 25.73],
#  ['12-01-26', 27.81, 27.81],
#  ['12-01-26', 25.83, 25.83],
#  ['12-01-26', 21.83, 21.83]]

# %% [markdown]
# ---
# ### 7.2: Convert list to DataFrame

# %%
import pandas as pd
df=pd.DataFrame(rows,columns=['Date','Min_Temp','Max_Temp']) # This line converts a list of extracted values into a structured pandas DataFrame with named columns.
df.head()
# Out:
#        Date  Min_Temp  Max_Temp
# 0  07-01-26     18.01     18.01
# 1  07-01-26     16.28     17.43
# 2  08-01-26     14.81     15.88
# 3  08-01-26     18.07     18.07
# 4  08-01-26     24.17     24.17

# %% [markdown]
# ---
# ### 7.3: Aggregate to DAILY level

# %% [markdown]
# #Group by Date → find min and max for each group

# %%
daily_weather = df.groupby('Date')[['Min_Temp', 'Max_Temp']].agg({
    'Min_Temp': 'min',
    'Max_Temp': 'max'
}).reset_index()
daily_weather.head() 
#Compress 8 rows → 1 row per day using agg
# Out:
#        Date  Min_Temp  Max_Temp
# 0  07-01-26     16.28     18.01
# 1  08-01-26     14.81     26.12
# 2  09-01-26     15.78     26.61
# 3  10-01-26     15.63     26.91
# 4  11-01-26     16.27     27.71

# %% [markdown]
# ---
# ## Insights
#
# - The weather forecast data is available at 3-hour intervals and was aggregated to daily level for analysis.
# - Daily minimum and maximum temperatures vary noticeably across days, indicating clear intraday temperature fluctuations.
# - Peak temperatures are consistently higher than early morning or night-time temperatures.
# - Aggregating data to daily level makes the forecast easier to interpret and suitable for trend analysis.

# %% [markdown]
# ---
# ## Step 7.4: Clean Column Names

# %%
daily_weather=daily_weather.rename(columns={
    'Min_Temp':'Daily_Min_temp',
    'Max_Temp':'Daily_Max_temp'
})

# %%
daily_weather.head()
# Out:
#        Date  Daily_Min_temp  Daily_Max_temp
# 0  07-01-26           16.28           18.01
# 1  08-01-26           14.81           26.12
# 2  09-01-26           15.78           26.61
# 3  10-01-26           15.63           26.91
# 4  11-01-26           16.27           27.71

# %% [markdown]
# ---
# ## Step 7.5: Sort by Date

# %%
daily_weather=daily_weather.sort_values('Date')
daily_weather
# Required for plotting & forecasting to maintain chronological order
# Out:
#        Date  Daily_Min_temp  Daily_Max_temp
# 0  07-01-26           16.28           18.01
# 1  08-01-26           14.81           26.12
# 2  09-01-26           15.78           26.61
# 3  10-01-26           15.63           26.91
# 4  11-01-26           16.27           27.71
# 5  12-01-26           16.33           27.81

# %% [markdown]
# ## Step 7.6: Basic Validation

# %%
daily_weather.describe()
# Out:
#         Min_Temp   Max_Temp
# count   6.000000   6.000000
# mean   15.850000  25.528333
# std     0.587639   3.739521
# min    14.810000  18.010000
# 25%    15.667500  26.242500
# 50%    16.025000  26.760000
# 75%    16.277500  27.510000
# max    16.330000  27.810000

# %% [markdown]
# ## 7.7: Simple Visualization

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(daily_weather['Date'], daily_weather['Daily_Max_temp'], label='Daily Max Temp')
plt.plot(daily_weather['Date'], daily_weather['Daily_Min_temp'], label='Daily Min Temp')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.title('Daily Maximum Temperature Trend')
plt.xticks(rotation=45)

plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Step 7.8: Final Insights

# %% [markdown]
# - Weather forecast data is available at 3-hour intervals and was aggregated to daily level for analysis.
# - Daily minimum and maximum temperatures show noticeable variation across days.
# - Aggregated daily data simplifies interpretation and supports trend analysis.
# - Visual comparison of daily minimum and maximum temperatures highlights intraday temperature range across the forecast period.
# - The resulting dataset is suitable for reporting and further time-series analysis.
